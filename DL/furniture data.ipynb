# %%
import pandas as pd
import json

# %%
val = pd.read_json('validation.json')
val.head()
# Out:
#                         annotations  \
# 0   {'image_id': 1, 'label_id': 38}
# 1   {'image_id': 2, 'label_id': 63}
# 2   {'image_id': 3, 'label_id': 33}
# 3  {'image_id': 4, 'label_id': 126}
# 4   {'image_id': 5, 'label_id': 18}
#
#                                               images
# 0  {'url': ['http://www.ghs.net/public/images/fb/...
# 1  {'url': ['https://img.alicdn.com/imgextra/TB2c...
# 2  {'url': ['http://static-news.17house.com/web/n...
# 3  {'url': ['http://img000.hc360.cn/g6/M07/CB/88/...
# 4  {'url': ['https://img.alicdn.com/imgextra/T1sL...

# %%
val['image_id'] = val.annotations.map(lambda x: x['image_id'])
val['label_id'] = val.annotations.map(lambda x: x['label_id'])
val['url'] = val.images.map(lambda x: x['url'][0])
# val.drop(columns=['annotations', 'images'], inplace=True)
val.head()
# Out:
#                         annotations  \
# 0   {'image_id': 1, 'label_id': 38}
# 1   {'image_id': 2, 'label_id': 63}
# 2   {'image_id': 3, 'label_id': 33}
# 3  {'image_id': 4, 'label_id': 126}
# 4   {'image_id': 5, 'label_id': 18}
#
#                                               images  image_id  label_id  \
# 0  {'url': ['http://www.ghs.net/public/images/fb/...         1        38
# 1  {'url': ['https://img.alicdn.com/imgextra/TB2c...         2        63
# 2  {'url': ['http://static-news.17house.com/web/n...         3        33
# 3  {'url': ['http://img000.hc360.cn/g6/M07/CB/88/...         4       126
# 4  {'url': ['https://img.alicdn.com/imgextra/T1sL...         5        18
#
#                                                  url
# 0  http://www.ghs.net/public/images/fb/3d/51/3beb...
# 1  https://img.alicdn.com/imgextra/TB2chFei9YH8KJ...
# 2  http://static-news.17house.com/web/news/201602...
# 3  http://img000.hc360.cn/g6/M07/CB/88/wKhQsFNNVJ...
# ...

# %%
val.columns
# Out:
# Index(['annotations', 'images', 'image_id', 'label_id', 'url'], dtype='object')

# %%
val.drop(['annotations','images'],axis = 1,inplace=True)
val.head(30)
# Out:
#     image_id  label_id                                                url
# 0          1        38  http://www.ghs.net/public/images/fb/3d/51/3beb...
# 1          2        63  https://img.alicdn.com/imgextra/TB2chFei9YH8KJ...
# 2          3        33  http://static-news.17house.com/web/news/201602...
# 3          4       126  http://img000.hc360.cn/g6/M07/CB/88/wKhQsFNNVJ...
# 4          5        18  https://img.alicdn.com/imgextra/T1sLtpFH8aXXXX...
# 5          6       125  https://img.alicdn.com/imgextra/TB2xKYDhFXXXXX...
# 6          7        43  https://img14.360buyimg.com/imgzone/jfs/t8062/...
# 7          8        13  https://img.alicdn.com/imgextra/TB22lAgXkfb_uJ...
# 8          9        74  https://img11.360buyimg.com/imgzone/jfs/t862/2...
# 9         10        29  https://img.alicdn.com/imgextra/TB2cV9JcpXXXXa...
# 10        11        63  https://img.alicdn.com/imgextra/TB2mC4Ncb0kpuF...
# 11        12        26  https://img14.360buyimg.com/imgzone/jfs/t15433...
# ...

# %%
labels = val.label_id.unique()

# %%
img_ids = val.image_id.unique()

# %%
import urllib
import requests
import os
for j in range(6400):
    for i in labels:
#         if not os.path.exists(str(i)):
#             os.mkdir(str(i))
        
#         os.chdir(str(i))
        image_url = val.url[j]
        
        img_data = requests.get(image_url,timeout=30).content
        
#         if img_data.status_code in [400,415]:

#             break
        with open('image_id_'+ str(j)+'_'+str(i)+'.jpg', 'wb') as handler:
            handler.write(img_data) 
#             os.chdir('C:/Users/HP/ML/furniture/')
            i=i+1
        j=j+1
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-4fe8a6b0c855> in <module>()
#      10         image_url = val.url[j]
#      11
# ---> 12         img_data = requests.get(image_url,timeout=30).content
#      13
#      14 #         if img_data.status_code in [400,415]:
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ...
