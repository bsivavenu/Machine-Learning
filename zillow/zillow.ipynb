# %%
import pandas as pd
import numpy as np

pd.options.mode.chained_assignment = None
pd.options.display.max_columns = 500

# %%
train = pd.read_csv('c:/Users/HP/Desktop/zilllow/train_2016_v2.csv')
# properties = pd.read_csv('c:/Users/HP/Desktop/zilllow/properties_2016.csv',engine='python',header=None,nrows = 500)

# %%
train.shape
# Out:
# (90275, 3)

# %%
reader = pd.read_csv('c:/Users/HP/Desktop/zilllow/properties_2016.csv')
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
reader.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-2ece75500033> in <module>()
# ----> 1 reader.shape
#
# AttributeError: 'TextFileReader' object has no attribute 'shape'

# %%
# for i in range(3):
# %time reader.get_chunk(5)
#     i+=1
# Out:
# Wall time: 8 ms
#         parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 100000  13967756                    NaN                       NaN
# 100001  13967971                    NaN                       NaN
# 100002  13968409                    NaN                       NaN
# 100003  13968555                    NaN                       NaN
# 100004  13968793                    NaN                       NaN
#
#         basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 100000           NaN          3.0         3.0                  NaN
# 100001           NaN          2.5         5.0                  NaN
# 100002           NaN          3.0         4.0                  NaN
# 100003           NaN          3.0         4.0                  NaN
# 100004           NaN          2.0         4.0                  NaN
#
#         buildingqualitytypeid  calculatedbathnbr  decktypeid  \
# 100000                    NaN                3.0         NaN
# ...

# %%
# Out:
# <bound method TextFileReader.read of <pandas.io.parsers.TextFileReader object at 0x00000000095A52E8>>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for c in chunk.columns:
    chunk[c]=chunk[c].fillna(-1)
    if chunk[c].dtype == 'object':
        lbl = LabelEncoder()
        lbl.fit(list(chunk[c].values))
        chunk[c] = lbl.transform(list(chunk[c].values))
