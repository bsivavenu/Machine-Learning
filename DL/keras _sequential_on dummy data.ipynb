# %% [markdown]
# #### this notebook shows different ways of modeling in keras in both sequential and functional api.

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
import numpy as np

# %%
np.random.seed(10)
data_train = np.random.random((1000,100))
label_train = np.random.randint(2,size=(1000,1))
data_test = np.random.random((200,100))
label_test = np.random.randint(2,size=(200,1))

# %%
model =Sequential()
model.add(Dense(32,activation='relu',input_shape=(100,)))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_13 (Dense)             (None, 32)                3232
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 33
# ...
# Total params: 3,265
# Trainable params: 3,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(data_train,label_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 0s 149us/step - loss: 0.6643 - acc: 0.6060
# Epoch 2/100
# 1000/1000 [==============================] - 0s 114us/step - loss: 0.6633 - acc: 0.5950
# Epoch 3/100
# 1000/1000 [==============================] - 0s 141us/step - loss: 0.6611 - acc: 0.6130
# Epoch 4/100
# 1000/1000 [==============================] - 0s 160us/step - loss: 0.6561 - acc: 0.6230
# Epoch 5/100
# 1000/1000 [==============================] - 0s 130us/step - loss: 0.6579 - acc: 0.6290
# Epoch 6/100
# 1000/1000 [==============================] - 0s 131us/step - loss: 0.6536 - acc: 0.6200
# Epoch 7/100
# 1000/1000 [==============================] - 0s 145us/step - loss: 0.6490 - acc: 0.6320
# Epoch 8/100
# 1000/1000 [==============================] - 0s 132us/step - loss: 0.6502 - acc: 0.6320
# Epoch 9/100
# 1000/1000 [==============================] - 0s 131us/step - loss: 0.6471 - acc: 0.6310
# Epoch 10/100
# ...

# %%
score = model.evaluate(data_test,label_test)
print('accuracy:',score[0]*100,'%')
print('loss:',score[1]*10,'%')
# Out:
# 200/200 [==============================] - 0s 165us/step
# accuracy: 94.3054018021 %
# loss: 5.15 %

# %% [markdown]
# ### the below code is keras model on dummy data with functional api

# %%
from keras.models import Input
from keras.models import  Model

# %%
inputs = Input(shape=(100,))
x = Dense(32,activation='relu')(inputs)
predictions = Dense(1,activation='sigmoid')(x)

# %%
model = Model(inputs=inputs,outputs=predictions)

# %%
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                3232
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 33
# ...
# Total params: 3,265
# Trainable params: 3,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(data_train,label_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 1s 775us/step - loss: 0.7041 - acc: 0.5130
# Epoch 2/100
# 1000/1000 [==============================] - 0s 135us/step - loss: 0.6942 - acc: 0.5050
# Epoch 3/100
# 1000/1000 [==============================] - 0s 158us/step - loss: 0.6895 - acc: 0.5330
# Epoch 4/100
# 1000/1000 [==============================] - 0s 145us/step - loss: 0.6848 - acc: 0.5560
# Epoch 5/100
# 1000/1000 [==============================] - 0s 132us/step - loss: 0.6854 - acc: 0.5620 0s - loss: 0.6848 - acc: 0.561
# Epoch 6/100
# 1000/1000 [==============================] - 0s 154us/step - loss: 0.6804 - acc: 0.5760 0s - loss: 0.6800 - acc: 0.572
# Epoch 7/100
# 1000/1000 [==============================] - 0s 127us/step - loss: 0.6779 - acc: 0.5920
# Epoch 8/100
# 1000/1000 [==============================] - 0s 131us/step - loss: 0.6726 - acc: 0.5880
# Epoch 9/100
# 1000/1000 [==============================] - 0s 141us/step - loss: 0.6677 - acc: 0.5860
# ...

# %%
score = model.evaluate(data_test,label_test)
print('accuracy:',score[0]*100,'%')
print('loss:',score[1]*100,'%')
# Out:
# 200/200 [==============================] - 0s 160us/step
# accuracy: 98.8391458988 %
# loss: 46.5 %

# %%
pred = model.predict(data_test[13:14])
if pred > 0.5:
    pred_value = 1
else:
    pred_value = 0
true = label_test[13]
print('pred probability:',pred,'\n','pred label:',pred_value,'\n','true label:',true)
# Out:
# pred probability: [[ 0.44715947]]
#  pred label: 0
#  true label: [0]
