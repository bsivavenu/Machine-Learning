# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
lyrics = pd.read_csv('c:/Users/HP/Desktop/songdata.csv')

# %%
lyrics.head(3)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...

# %%
lyrics = lyrics.drop('link',axis= 1)
lyrics.head(3)
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...

# %%
art_list = lyrics['artist'].unique()
len(art_list)
# Out:
# 643

# %%
lyrics.groupby('artist').describe()
# Out:
#                              song                                            \
#                             count unique                                top
# artist
# 'n Sync                        93     93                    Beegee's Medley
# ABBA                          113    113                Take A Chance On Me
# Ace Of Base                    74     74                       Show Me Love
# Adam Sandler                   70     70                     Technical Foul
# Adele                          54     54             Melt My Heart To Stone
# Aerosmith                     171    171                    Girls Of Summer
# Air Supply                    174    174                         I Want You
# Aiza Seguerra                  25     25                   One And Only You
# Alabama                       187    187                         Lovin' Man
# Alan Parsons Project          102    102               Nothing Left To Lose
# ...

# %%
lyrics_abba = lyrics.loc[lyrics.artist == 'ABBA']
# sns.distplot()
lyrics_abba
# Out:
#     artist                                      song  \
# 0     ABBA                     Ahe's My Kind Of Girl
# 1     ABBA                          Andante, Andante
# 2     ABBA                            As Good As New
# 3     ABBA                                      Bang
# 4     ABBA                          Bang-A-Boomerang
# 5     ABBA                        Burning My Bridges
# 6     ABBA                                 Cassandra
# 7     ABBA                                Chiquitita
# 8     ABBA                               Crazy World
# 9     ABBA                           Crying Over You
# 10    ABBA                                     Dance
# 11    ABBA                             Dancing Queen
# 12    ABBA                               Disillusion
# 13    ABBA                     Does Your Mother Know
# 14    ABBA                               Dream World
# 15    ABBA                            Dum Dum Diddle
# 16    ABBA                                     Eagle
# ...

# %%
text_corpus = []
for song in lyrics['text']:
    words = song.lower().split()
    text_corpus.append(words)

# %%
import gensim.models.word2vec as w2v
import gensim.models.word2vec as w2v
import multiprocessing
import os
import re
import pprint
import sklearn.manifold
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-8f66722c68c5> in <module>()
# ----> 1 import gensim.models.word2vec as w2v
#       2 import gensim.models.word2vec as w2v
#       3 import multiprocessing
#       4 import os
#       5 import re
#
# ModuleNotFoundError: No module named 'gensim'

# %%
num_features = 50
min_word_count = 1
context_size = 7
downsampling = 1e-1
seed = 1
songs2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

songs2vec.build_vocab(text_corpus)
print (len(text_corpus))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-457d2cae7b3d> in <module>()
#       4 downsampling = 1e-1
#       5 seed = 1
# ----> 6 songs2vec = w2v.Word2Vec(
#       7     sg=1,
#       8     seed=seed,
#
# NameError: name 'w2v' is not defined
